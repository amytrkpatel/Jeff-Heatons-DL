# %% [markdown]
# # **Introduction to Python**

# %%
#Begining with hello world!
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Single Line Comments:

# %%
print("The line after # is a single line comment") #This is a comment
# Out:
# The line after # is a single line comment

# %% [markdown]
# Multi Line Comments

# %%
"""This is a
multi line
comment"""
print("multi-line comment example!")
# Out:
# multi-line comment example!

# %% [markdown]
# Multiple Lines in a Print Statement:

# %%
print("""This
is a
multi-line
print
statement""")
# Out:
# This
# is a
# multi-line
# print
# statement

# %% [markdown]
# Single quote and double quote doesn't make any difference in print statement

# %%
print('This is a string in Single quotes')
print("This is a string in double quotes")
# Out:
# This is a string in Single quotes
# This is a string in double quotes

# %% [markdown]
# Numbers do not need quotes

# %%
print(43)
# Out:
# 43

# %% [markdown]
# Variables can hold string or number values

# %%
a = 10
b = "ball"
print(a)
print(b)
# Out:
# 10
# ball

# %% [markdown]
# # Formatted or interpolated string
# You can mix strings and variables in a print statement. This is called formatting string. The variables must be inside curly braces. In Python, this type of string is generally called an f-string. The f-string is denoted by placing an "f" just in front of the opening single or double quote that begins the
# string.

# %%
a = 10
print(f"the f-value of a is {a}")
# Out:
# the f-value of a is 10

# %% [markdown]
# format() strings:

# %%
print("the another way of writing f-value of a plus 5 is {0}".format(a+5))
# Out:
# the another way of writing f-value of a plus 5 is 15

# %% [markdown]
# Preferred way is f-string:

# %%
a = 5
print(f'Value of a is {a}') #this is the preferred way
print('a is {}'.format(a))
print('a is ' + str(a))
print('a is %d' %(a))
# Out:
# Value of a is 5
# a is 5
# a is 5
# a is 5

# %% [markdown]
# #If statements
# These if-statements are how Python
# defines blocks of code to execute together. A block usually begins after a colon and includes any lines at the
# same level of indent
#
#
# ```
# if a == 5:
#     do this
# elif a== 6:
#     do this
# else:
#     do this.
# ```

# %% [markdown]
# Loop:
# ```
# for x in range(1,100):
#   print(x)
# ```
# this will print 1 to 99
