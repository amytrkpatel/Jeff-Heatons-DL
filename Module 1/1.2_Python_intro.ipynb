# %% [markdown]
# # **Introduction to Python**

# %%
#Begining with hello world!
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Single Line Comments:

# %%
print("The line after # is a single line comment") #This is a comment
# Out:
# The line after # is a single line comment

# %% [markdown]
# Multi Line Comments

# %%
"""This is a
multi line
comment"""
print("multi-line comment example!")
# Out:
# multi-line comment example!

# %% [markdown]
# Multiple Lines in a Print Statement:

# %%
print("""This
is a
multi-line
print
statement""")
# Out:
# This
# is a
# multi-line
# print
# statement

# %% [markdown]
# Single quote and double quote doesn't make any difference in print statement

# %%
print('This is a string in Single quotes')
print("This is a string in double quotes")
# Out:
# This is a string in Single quotes
# This is a string in double quotes

# %% [markdown]
# Numbers do not need quotes

# %%
print(43)
# Out:
# 43

# %% [markdown]
# Variables can hold string or number values

# %%
a = 10
b = "ball"
print(a)
print(b)
# Out:
# 10
# ball

# %% [markdown]
# You can mix strings and variables in a print statement. This is called formatting string. The variables must be inside curly braces.

# %%
a = 10
print("the f-value of a is {0}".format(a))
print("or")
print(f"the another way of writing f-value of a plus 5 is {a+5}")
print()
# Out:
# the f-value of a is 10
# or
# the another way of writing f-value of a plus 5 is 15

# %% [markdown]
# Preferred way is f-string:

# %%
a = 5
print(f'Value of a is {a}')
# Out:
# Value of a is 5

# %% [markdown]
# if else in python:
#
#
# ```
# if a == 5:
#     do this
# elif a== 6:
#     do this
# else:
#     do this.
# ```

# %% [markdown]
# Loop:
# ```
# for x in range(1,100):
#   print(x)
# ```
# this will print 1 to 99
